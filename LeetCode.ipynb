# %% [markdown]
# # Content
#
# 1. [Binary Search](#1.-Binary-Search)
# 2. [Sorting](#2.-Sorting)
# 3. [Linked List](#3.-Linked-List)
# 4. [Queue & Stack](#4.-Queue-&-Stack)
# 5. [Binary Tree & Binary Search Tree](#5.-Binary-Tree-&-Binary-Search-Tree)
# 6. [Heap](#6.-Heap)
# 7. [Graph Search](#7.-Graph-Search)
# 8. [Hash Table](#8.-Hash-Table)
# 9. [String](#9.-String)

# %% [markdown]
# # 1.  Binary Search

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 2. Sorting

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 3. Linked List

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 4. Queue & Stack

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 5. Binary Tree & Binary Search Tree

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 6. Heap

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 7. Graph Search

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 8. Hash Table

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard

# %% [markdown]
# # 9. String

# %% [markdown]
# ## Easy

# %% [markdown]
# ## Medium

# %% [markdown]
# ## Hard
