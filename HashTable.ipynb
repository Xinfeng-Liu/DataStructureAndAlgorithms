# %% [markdown]
# * Hash Table: a data structure that provides a mapping from keys to values using a technique called hashing. HTs are often used to track item frequencies.
#
# * Hash Function H(x): a function that maps a key 'x' to a whole numer in a fixed range. We can define hash functions for arbitrary objects such as strings, lists, tuples, etc...
#
# * Hashable: If a key of type T is **immutable**, and we have a hash function H(k) defined for all keys k of type T, then we say a key of type T is hashable.

# %% [markdown]
# Hash Function Properties
# 1. If H(x) = H(y), then objects x and y might be equal, but if H(x) != H(y), then x and y are certainly not equal
#     * Can be used to accelerate comparing x and y.
# 2. A hash function H(x) must be deterministic. This means that if H(x) = y, then H(x) must always produce y and never another value.
# 3. We try to make **uniform** hash function to minimize the number of hash collisions(H(x) = H(y)).

# %% [markdown]
# In python, dictionary is the implementation of hash table
